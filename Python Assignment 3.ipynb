# %%
# Creating a class
class Employee:
    ID = ""  #     Id is a global variable

#     constructor
    def __init__(self, ID):
        self.ID = ID

# function
    def EmployeefirstName(self, ):
        fName = "Humayan"
        return fName
    
    def EmployeelastName(self, ):
        lName = "Kabir"
        return lName
    
    def EmployeeDept(self, ):
        dept = "CSE"
        return dept
    def EmployeeJoining(self, ):
        join = "1st of January, 2021"
        return join
    
E = Employee("E0000001")

# %%
E.ID
# Out:
# 'E0000001'

# %%
E.EmployeefirstName()
# Out:
# 'Humayan'

# %%
E.EmployeelastName()
# Out:
# 'Kabir'

# %%
E.EmployeeDept()
# Out:
# 'CSE'

# %%
E.EmployeeJoining()
# Out:
# '1st of January, 2021'
